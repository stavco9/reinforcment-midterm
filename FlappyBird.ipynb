# %% [markdown]
# <a href="https://colab.research.google.com/github/stavco9/reinforcment-midterm/blob/heuristic/FlappyBird.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installs

# %% [markdown]
# ## Imports

# %%
# !git clone https://github.com/ntasfi/PyGame-Learning-Environment
# !pip install gym_ple
# !pip install -e ./PyGame-Learning-Environment
# !pip install pyvirtualdisplay
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev
# Out:
# fatal: destination path 'PyGame-Learning-Environment' already exists and is not an empty directory.
# Requirement already satisfied: gym_ple in /usr/local/lib/python3.10/dist-packages (0.3)
# Obtaining file:///content/PyGame-Learning-Environment
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ple==0.0.1) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from ple==0.0.1) (11.0.0)
# Installing collected packages: ple
#   Attempting uninstall: ple
#     Found existing installation: ple 0.0.1
#     Uninstalling ple-0.0.1:
#       Successfully uninstalled ple-0.0.1
#   Running setup.py develop for ple
# Successfully installed ple-0.0.1
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (3.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# freeglut3-dev is already the newest version (2.8.1-6).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.12).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import sys
sys.path.append('/content/PyGame-Learning-Environment')
from ple.games.flappybird import FlappyBird
from ple import PLE
from gym import spaces
import IPython
import numpy as np
import gym
import os
import pyvirtualdisplay
import base64
import warnings
import imageio
from abc import ABC, abstractmethod
warnings.filterwarnings("ignore")
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom

# %% [markdown]
# ## Utility function to display episode

# %%
def embed_mp4(filename):
  """Embeds an mp4 file in the notebook."""
  video = open(filename,'rb').read()
  b64 = base64.b64encode(video)
  tag = '''
  <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
  Your browser does not support the video tag.
  </video>'''.format(b64.decode())

  return IPython.display.HTML(tag)
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()

# %% [markdown]
# ## Environment

# %% [markdown]
# ### Environment Summary
#
# This environment simulates the *Flappy Bird* game, where the agent controls the bird’s vertical position to navigate through gaps in pipes. Built on OpenAI’s `gym.Env` class, the environment allows interaction through standard functions like `step`, `reset`, and `render`.
#
# **Key Components**
#
# - **Observation Space**: The observation space includes 8 integer values, each representing a different aspect of the game state. These include:
#   - `"player_y"`: The bird's vertical position.
#   - `"player_vel"`: The bird's vertical velocity.
#   - `"next_pipe_dist_to_player"`: Horizontal distance to the next pipe.
#   - Additional features: Positions of the top and bottom of the next two pipes, enabling the agent to anticipate upcoming gaps.
#
# - **Action Space**: This is a discrete space with two actions:
#   - `0`: No flap (bird falls due to gravity).
#   - `1`: Flap (bird moves upward).
# - **Using the Environment**
#
#   - **Step:**
#     The `step` function returns four parameters: `obs`, `reward`, `done`, and `info`.
#
#     - **`obs`**: The new observation after applying the action.
#     - **`reward`**: The reward received for the action.
#     - **`done`**: A boolean indicating whether the episode has ended.
#     - **`info`**: A dictionary containing additional information. In this environment, the `info` dictionary includes a `"score"` entry that indicates how many pipes the bird has passed since the beginning of the episode.
#   - **Reset**
#     The `reset` function restores the environment to its initial state and returns the observation of that state.
#
#   - **Render**
#     The `render` function returns an image of the current state as a NumPy array (`np.array`).
#
#   See the `Running the environment` section below for an example of how to use it.
#
# - **Customizable Parameters**:
#   - **`pipe_gap`**: This controls the vertical gap between pipes. The default is set to `80`, providing a moderate challenge.
#   - **`custom_obs`** and **`custome_observation_map`**: Setting `custom_obs=True` instructs the environment to use a custom `observation_map` specified by the user, rather than the default map. When using a custom observation map, the user must also provide a `preprocess` function compatible with the custom observation map to ensure the observations are correctly processed for the agent.
#
#   - **`preprocess`** and **`reward_shaping`**: Optional functions that allow the user to customize how observations and rewards are modified. The `preprocess` function transforms the raw observations according to the specified `observation_map`, while `reward_shaping` allows for custom adjustments to the reward structure, helping to align the environment with the agent’s learning goals.
#
#   See the `Custom observation and reward shaping example of usage` section below for an example of usage.

# %%
# to disable the python game window popup
os.environ["SDL_VIDEODRIVER"] = "dummy"

OBSERVATION_MAP = {0: 'player_y',
                   1: "player_vel",
                   2: "next_pipe_dist_to_player",
                   3: "next_pipe_top_y",
                   4: "next_pipe_bottom_y",
                   5: "next_next_pipe_dist_to_player",
                   6: "next_next_pipe_top_y",
                   7: "next_next_pipe_bottom_y",
}

class Game(gym.Env):
    def __init__(self, display_screen=False,
                 force_fps=True,
                 custom_obs=False,
                 pipe_gap=80,
                 custome_observation_map={},
                 preprocess=lambda x: x,
                 reward_shaping=lambda x, y, z: x):

        os.environ["SDL_VIDEODRIVER"] = "dummy"
        game = FlappyBird(pipe_gap=pipe_gap)  # define and initiate the environment
        self.env = PLE(game, fps=30, display_screen=display_screen,
                       force_fps=force_fps)
        self.env.init()
        # list of actions in the environment
        self.actions = self.env.getActionSet()
        # length of actions
        self.action_space = spaces.Discrete(len(self.actions))
        self.custom_obs = custom_obs
        self._observation_map = custome_observation_map if custom_obs else OBSERVATION_MAP
        self.preprocess = preprocess
        self.reward_shaping = reward_shaping
        self.score = 0

    @property
    def observation_space(self):
        return spaces.Box(low=0, high=512, shape=(len(self._observation_map),), dtype=int)

    def _get_rgb(self):
        return self.env.getScreenRGB().transpose(1, 0, 2)

    @property
    def observation_map(self):
        return self._observation_map

    def step(self, action):
        """Take the action chosen and update the reward"""
        reward = self.env.act(self.actions[action])
        if reward < 0:
          reward = -1

        if reward > 0:
          self.score += 1
        state = self.env.getGameState()
        terminal = self.env.game_over()
        reward = self.reward_shaping(reward, terminal, env)
        info = {'score':self.score}
        return self.preprocess(np.array(list(state.values())).astype(int)), reward, terminal, info

    def getGameState(self):
        '''
        PLEenv return gamestate as a dictionary. Returns a modified form
        of the gamestate only with the required information to define the state
        '''
        state = self.env.getGameState()
        h_dist = state['next_pipe_dist_to_player']
        v_dist = state['next_pipe_bottom_y'] - state['player_y']
        vel = state['player_vel']

        return ' '.join([str(vel), str(h_dist), str(v_dist)])

    def reset(self):
        """Resets the game to start a new game"""
        self.env.reset_game()
        state = self.env.getGameState()
        self.score = 0
        return self.preprocess(np.array(list(state.values())).astype(int))

    def render(self, mode='human'):
        """Render the game"""
        return self._get_rgb()

    def seed(self, seed):
        rng = np.random.RandomState(seed)
        self.env.rng = rng
        self.env.game.rng = self.env.rng

        self.env.init()

# %%
env = Game(custom_obs=False)

# %% [markdown]
# ### Observation space

# %%
print(f"observation space: {env.observation_space}")
for feaure, des in env.observation_map.items():
  print(f"feaure: {feaure} -> {des}")
# Out:
# observation space: Box(0, 512, (8,), int64)
# feaure: 0 -> player_y
# feaure: 1 -> player_vel
# feaure: 2 -> next_pipe_dist_to_player
# feaure: 3 -> next_pipe_top_y
# feaure: 4 -> next_pipe_bottom_y
# feaure: 5 -> next_next_pipe_dist_to_player
# feaure: 6 -> next_next_pipe_top_y
# feaure: 7 -> next_next_pipe_bottom_y

# %% [markdown]
# In this *Flappy Bird* environment, the `Box` type represents a `Discrete` observation space in OpenAI's Gym, providing the agent with a range of values in each dimension of the environment. Here’s what each part means:
#
# * **Box**: This type of space is used to define a `Discrete`  range of values for each observation dimension. Here, it represents an 8-dimensional vector.
# * **(0, 512)**: Each dimension within this space can take values from 0 to 512, which corresponds to the pixel boundaries of the game.
# * **(8,)**: This shape indicates that there are 8 distinct variables in the observation vector, each capturing a critical feature of the environment.
# * **int64**: Each value in the vector is an integer of 64-bit precision.
#
# In summary, `Box(0, 512, (8,), int64)` represents an 8-dimensional vector space where each element is an integer from 0 to 512. Each dimension corresponds to a specific aspect of the *Flappy Bird* environment:
#
# 1. **Player Y Position**: The vertical position of the bird, representing its height on the screen.
# 2. **Player Velocity**: The bird’s current velocity, which impacts its movement and helps determine when to flap.
# 3. **Distance to Next Pipe**: The horizontal distance between the bird and the next pipe, crucial for timing flaps.
# 4. **Next Pipe Top Y Position**: The vertical position of the top of the next pipe, helping the bird gauge the gap.
# 5. **Next Pipe Bottom Y Position**: The vertical position of the bottom of the next pipe, providing further data for navigating the gap.
# 6. **Distance to Next-Next Pipe**: The horizontal distance to the pipe after the next one, giving the bird foresight into upcoming obstacles.
# 7. **Next-Next Pipe Top Y Position**: The vertical position of the top of the pipe after the next one, extending the bird's view of upcoming gaps.
# 8. **Next-Next Pipe Bottom Y Position**: The vertical position of the bottom of the pipe after the next one, for additional planning.
#
# Together, these dimensions offer the agent a detailed snapshot of the environment, helping it make decisions based on its position, velocity, and the layout of both current and upcoming obstacles.

# %% [markdown]
# ### Action space

# %%
env.action_space
# Out:
# Discrete(2)

# %% [markdown]
# In this *Flappy Bird* environment, the `Discrete(2)` action space defines the possible actions the agent can take, using a finite set of discrete values:
#
# * **Discrete**: This type of space is used when there are a limited number of distinct actions.
# * **2**: The number of actions available, represented by values 0 and 1.
#
# For *Flappy Bird*, these actions correspond to:
#   * **0**: Do nothing (the bird continues to fall due to gravity).
#   * **1**: Flap (the bird moves upward briefly).
#
# In summary, `Discrete(2)` defines an action space with two possible actions: allowing the bird to either continue falling or flap to move upward, which is essential for navigating the gaps between pipes.

# %% [markdown]
# ### Rewards
#
# *Reward Structure:*
#
#
#
# *   **Positive Reward**: For each pipe successfully passed, the agent receives a reward of **+1**.
# *   **Negative Reward**: Upon reaching any terminal state, the agent receives a penalty of **-1**.
# *   **Zero Reward**: Any other senario the reward is **0**

# %% [markdown]
# ### Running the environmen

# %%
env = Game()
env.seed(42)
obs = env.reset()
video_filename = '/content/vid.mp4'
max_steps = 100
# Evaluation
with imageio.get_writer(video_filename, fps=24) as video:
  obs = env.reset()
  done = False
  total_reward = 0
  for i, step in enumerate(range(max_steps)):
      action = env.action_space.sample()
      obs, reward, done, info = env.step(action)
      next_obs = obs  # Get agent's position directly from the environment
      total_reward += reward
      re = env.render()
      video.append_data(re)
      if done:
        score = info['score']
        print("Sum of rewards =", total_reward, ", Number of steps=", step, "score: ", score)
        print(f"total steps: {i}")
        break
embed_mp4(video_filename)
# Out:
# Sum of rewards = -1.0 , Number of steps= 53 score:  0
# total steps: 53
#   <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#   Your browser does not support the video tag.
#   </video>

# %% [markdown]
# ### Custom observation and reward shaping example of usage

# %%
custom_obs_mapping = {0: "average",
                      1: 'sum'}

# meaningless preprocess method that average and sums all of the original features
preprocess = lambda x: np.array([np.mean(x), np.sum(x)])

# meaningless reward shaping method that added 1 to each original reward
reward_shaping = lambda x, y, z: x+1

env = Game(custom_obs=True,
           custome_observation_map=custom_obs_mapping,
           preprocess=preprocess,
           reward_shaping=reward_shaping)
env.seed(42)
obs = env.reset()

print(f"observation space: {env.observation_space}")
for feaure, des in env.observation_map.items():
  print(f"feaure: {feaure} -> {des}")

print(f"reset: {obs}")
print("#"*100, end="\n\n")
video_filename = '/content/vid.mp4'
max_steps = 100
# Evaluation
with imageio.get_writer(video_filename, fps=24) as video:
  obs = env.reset()
  done = False
  total_reward = 0
  for step in range(max_steps):
      action = env.action_space.sample()
      obs, reward, done, info = env.step(action)
      next_obs = obs  # Get agent's position directly from the environment
      total_reward += reward
      re = env.render()
      video.append_data(re)
      if done:
        score = info['score']
        print("Sum of rewards =", total_reward, ", Number of steps=", step, "score: ", score)
        break
embed_mp4(video_filename)
# Out:
# observation space: Box(0, 512, (2,), int64)
# feaure: 0 -> average
# feaure: 1 -> sum
# reset: [ 197.5 1580. ]
# ####################################################################################################
#
# Sum of rewards = 48.0 , Number of steps= 48 score:  0
#   <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#   Your browser does not support the video tag.
#   </video>

# %% [markdown]
# # Your Work begins here

# %% [markdown]
# ## Preprocess

# %% [markdown]
# **Define the `preprocess` Method**
#
# - Create a function called `preprocess` that takes an observation as input.
# - The purpose of this function is to transform the raw observation into a format that optimizes learning for the agent. Use your creativity to design an effective preprocessing strategy for this task.
#
# **Suggested Approaches:**
# - **Normalization or Scaling**: Adjust observation values to a common range, such as $0$ to $1$ or $0$ to $N$, to improve stability in the learning process.
# - **Feature Extraction**: Emphasize key features in the observation that are crucial for achieving the environment's goals.
# - **Dimensionality Reduction**: Simplify the observation by removing or combining less significant parts to streamline learning and reduce complexity.
#
# **Compression and Q-Table Size**
# - Reducing the complexity of the observation, through techniques like scaling, normalization, or removing redundant features, effectively compresses the data. This compression simplifies the agent’s perception of the environment, helping it focus on the most relevant information.
# - In discrete environments, reducing observation dimensionality directly impacts the size of the Q-table. By compressing the observation space, you decrease the number of possible states, which makes the Q-table smaller and easier to manage. This reduction in Q-table size not only conserves memory but can also enhance learning efficiency.
#
# Use these ideas to explain how your preprocessing strategy compresses the observation space and helps the agent handle the environment more effectively.
#
# **Rationalize Your Preprocessing Choices**
#
# - Include a brief explanation of your preprocessing choices. Explain why you believe this approach will improve the agent's learning efficiency and performance.
# - Discuss how these adjustments make the observations more interpretable or manageable for the learning algorithm.
#
# **Important**
# - The maximum value on the **Vertical** axis is **512**.
# - The maximum value on the **Horizontal** axis is **288**.

# %%
# Observation map
custome_observation_map = {} # assing each action with a description of the feature meaning
custome_observation_map = OBSERVATION_MAP  # Using the default one for starters


def preprocess(obs):
  """
  insert your preprocessing code here
  """
  state_repr = []
  for i, (feaure, des) in enumerate(env.observation_map.items()):
    state_repr.append(obs[i])
    print(f"{des} (feaure {feaure}#): {obs[i]}")
  return obs

# %% [markdown]
# ## Reward shaping

# %% [markdown]
# ### Define a Reward Shaping Strategy
#
# **Reward shaping** means adjusting the rewards given to the agent to encourage desired actions and help it learn faster. In *Flappy Bird*, the goal is to create rewards that guide the bird to survive longer and avoid hitting pipes.
#
# **Steps for Reward Shaping:**
#
# 1. **Identify Desired Behaviors**:
#    - Decide which behaviors you want to encourage. For example, flapping at the right time to pass through pipes or avoiding unnecessary flaps could be rewarded.
#
# 2. **Design Rewards**:
#    - Use rewards that motivate the bird to take helpful actions without distracting from the main goal (staying alive). Here are some ideas:
#      - **Survival Reward**: Give a small reward for each step the bird survives.
#      - **Penalty for Hitting Pipes**: Apply a negative reward (penalty) when the bird crashes into a pipe.
#     - **Passing Through Pipes**: Provide a positive reward each time the bird successfully passes through a pipe.
#
#
# 3. **Explain Your Reward Choices**:
#    - Add an explanation for your reward design. Why did you decide to reward certain actions or apply penalties?
#    - Describe how your rewards help the bird focus on staying alive and navigating pipes effectively.
#    - Provide an example demonstrating the impact of your reward shaping logic, ideally by comparing performance graphs with and without reward shaping.
#
# 4. **Avoid Over-Shaping**:
#    - Avoid giving too many rewards for minor actions, as it could lead the bird to focus on short-term rewards instead of the main goal. Aim for a balance where the bird gets enough guidance without relying on intermediate rewards.
#
# **Q-Learning and Value Convergence**:
#    - Remember, shaping rewards impacts **Q-values** (the expected value of actions). When rewards are well-designed, the bird’s Q-values will better reflect valuable actions, helping it make smarter choices over time.
#
# Use these tips to develop a reward strategy that encourages the bird to navigate through pipes effectively while improving its learning.

# %%
def reward_shaping(reward, terminal, env):
  # Added a third argument, `env`, to the function supplied in the exercise
  """
  insert your preprocessing code here
  """

  # Punish terminal states (user lost)
  TERMINAL_PUNISHMENT = 10  # This sounds so evil
  if terminal:
    reward -= TERMINAL_PUNISHMENT

  return reward

# %% [markdown]
# ## Implementation of Learning Agents

# %% [markdown]
# Abstract Class for Implementing an On-Policy Agent
#
# Below is an abstract class to serve as a foundation for implementing an on-policy agent. Derive your agent from this class and implement the specific logic for your agent. Note that different agents may require additional parameters or functions to support their unique features and learning mechanisms.

# %%
from abc import ABC, abstractmethod

class OnPolicyAgent(ABC):
    def __init__(self, action_space, observation_space, gamma, learning_rate):
        """
        Initializes the on-policy RL agent.
        You can add more parameters
        Parameters:
        - action_space: The action space of the environment
        - observation_space: The observation space of the environment
        - gamma: Discount factor for future rewards
        - learning_rate: Learning rate for policy updates
        """
        self.action_space = action_space
        self.observation_space = observation_space
        self.gamma = gamma
        self.learning_rate = learning_rate
        self.policy = None  # Placeholder for policy (to be implemented in subclasses)

    @abstractmethod
    def select_action(self, observation, deterministic=False):
        """
        Select an action based on the current policy.

        Parameters:
        - observation: Current state observation from the environment
        -deterministic: Flag indicating whether to use a deterministic policy (default is False)
        Returns:
        - action: Chosen action based on the policy
        """
        pass

    @abstractmethod
    def update_policy(self, transition):
        """
        Update the policy based on the current transition.

        Parameters:
        - transition: Data collected from interactions with the environment (tuple of zero or more values such as acion, reward etc...)
        """
        pass

    @abstractmethod
    def train(self, env, num_episodes, log_every):
        """
        Train the agent over a specified number of episodes.

        Parameters:
        - env: The environment to train in
        - num_episodes: Number of training episodes
        """
        pass

    @abstractmethod
    def save_policy(self, file_path):
        """
        Save the current policy to a file.

        Parameters:
        - file_path: Path to the file where the policy should be saved
        """
        pass

    @abstractmethod
    def load_policy(self, file_path):
        """
        Load a policy from a file.

        Parameters:
        - file_path: Path to the file from which the policy should be loaded
        """
        pass

    @abstractmethod
    def run_policy(self, env):
        """
        Run the loaded policy in the environment for one episode.

        Parameters:
        - env: The environment in which to run the policy

        Returns:
        - total_reward: Total reward accumulated in the episode
        """
        pass

# %% [markdown]
# ## Training

# %% [markdown]
# #### Experimentation Instructions
#
# In this section, you will conduct a series of experiments to solve the environment using your on-policy agent. Follow these guidelines for a clear and comprehensive presentation of your work:
#
# 1. **Design and Run Experiments**:
#    - Perform at least **5 distinct experiments** with your agent, including:
#      - **2 unsuccessful experiments** where the agent fails to learn the environment (reaching a score below the target).
#      - **1 successful experiment** where the agent achieves a score of **10** or higher. (Remember the score is define by the amount of pipes the agent has passed)
#
#    - *Note*: In practice, you are expected to try many configurations to observe various outcomes, even beyond these 3 experiments.
#
# 2. **Provide Detailed Summaries**:
#    - For each experiment, include:
#      - **Graphs** that illustrate the training process, such as reward progression, steps, score, and  any other relevant metrics (there is many more metrics that we can learn from).
#      - **Explanations of Hyperparameters**: Clearly describe the configuration of hyperparameters chosen for each experiment, and the reasoning behind these choices.
#      - **Preprocessing and Reward Shaping**: Explain any data preprocessing or reward shaping techniques applied, along with the motivation for these techniques.
#
# 3. **Analyze and Reflect**:
#    - **Result Analysis**: Analyze each experiment's outcome, focusing on why the agent may have succeeded or failed based on your configurations.
#    - **Insights and Deductions**: Draw insights from each experiment, noting what worked and what didn’t. Use these insights to refine your understanding of the environment and agent performance.
#
# 4. **Final Report**:
#    - **Synthesize Findings**: Compile all observations, insights, and analysis from your experiments into a final report. This report should showcase your learnings and demonstrate a deep understanding of the experimentation process.
#    - **Emphasis on Analysis**: The analysis of your results and the conclusions drawn are the most critical aspects of this exercise. Dedicate ample attention to this section, as it will reflect your ability to interpret and understand the agent’s learning process.
#
# **Remember**: The goal of this exercise is to experiment, learn, and iterate. Document your process thoroughly, as this will form the foundation of your report.

# %%
class TrivialPolicy(OnPolicyAgent):
    def __init__(self, action_space, observation_space, gamma, learning_rate):
        """
        Initializes the on-policy RL agent.
        You can add more parameters
        Parameters:
        - action_space: The action space of the environment
        - observation_space: The observation space of the environment
        - gamma: Discount factor for future rewards
        - learning_rate: Learning rate for policy updates
        """
        print(f"Initializing a trivial policy")
        print("Calling OnPolicyAgent's constructor")
        super().__init__(action_space, observation_space, gamma, learning_rate)
        print("Now initializing subclass")
        self.policy = None  # Placeholder for policy (to be implemented in subclasses)
        print(f"Gamma is {self.gamma}")

    def select_action(self, observation, deterministic=False):
        """
        Select an action based on the current policy.

        Parameters:
        - observation: Current state observation from the environment
        -deterministic: Flag indicating whether to use a deterministic policy (default is False)
        Returns:
        - action: Chosen action based on the policy
        """

        # NOTE: 0 is going UP and 1 is going DOWN, unlike instructions.

        print(f"select_action invoked")
        print(f"\tGot an observation object of type {type(observation)}")
        print(observation)
        obs = observation  # Renaming the var, but complying with super()'s signature

        def describe_observation(obs):
          # returns a string repr of the position relating the next pipe
          # can and should find a better place to put this function
          if obs[0] > obs[3]:
            position = "above"
          elif obs[0] < obs[4]:
            position = "below"
          else:
            position = "within"
          return position

        # Basic feature extraction
        gap_mid_point = (obs[3] + obs[4]) / 2
        above_middle = gap_mid_point - obs[0]
        movement_direction = "up" if obs[1] > 0 else "down"

        # Creating a verbal description of current state
        gap_position = describe_observation(obs)
        state_description = f"""
        This is what I understand regarding current observation:\n
        Bird at altitude {obs[0]},
        moving {movement_direction} at speed {abs(obs[1])} ({obs[1]}).\n
        The next pipe is {obs[2]} units away,
        with its top at {obs[3]} and bottom at {obs[4]}.\n
        This means that bird is {gap_position} the next gap.\n
        Distance from the middle of the gap: {above_middle}.\n
        We currently ignore the 'next next' pipe.
        """
        print(state_description)

        # Currently hard-coded action selection according to location related to midpoint of the next gap
        return 1 if above_middle > -9 else 0

    def update_policy(self, transition):
        """
        Update the policy based on the current transition.

        Parameters:
        - transition: Data collected from interactions with the environment (tuple of zero or more values such as acion, reward etc...)
        """
        print(f"update_policy invoked")
        print(f"\tGot a transition object of type {type(transition)}")

    def train(self, env, num_episodes, log_every):
        """
        Train the agent over a specified number of episodes.

        Parameters:
        - env: The environment to train in
        - num_episodes: Number of training episodes

        Here we need to invoke (in a loop)
          * `select_action`
          * get the reward somehow
          * `update_policy`
        """
        print(f"train invoked")
        print(f"\tGot an env object of type {type(env)}")
        print(f"\tARG num_episodes = {(num_episodes)}")
        print(f"\tARG log_every = {(log_every)}")

        video_filename = '/content/experiment1.mp4'
        max_steps = num_episodes  # is steps==episodes?
        print(f"Looping on {(max_steps)} steps")
        with imageio.get_writer(video_filename, fps=24) as video:
          print("Resetting environment and getting first observation")
          obs = env.reset()  # obs is now the initial state
          done = False
          total_reward = 0
          for step in range(max_steps):

            # log info
            if step % log_every == 0:
              print(f"Episode #{step}")

            # pick an action
            selected_action = self.select_action(obs)
            print(f"Selected action: {selected_action}")

            # perform the selected action
            obs, reward, done, info = env.step(selected_action)

            total_reward += reward
            print("rendering frame and appending to video")
            re = env.render()
            video.append_data(re)
            if done:
              score = info['score']
              print("Encountered a terminal state")
              print("Sum of rewards =", total_reward, ", Number of steps=", step, "score: ", score)
              break

        # print(f'Finished training. Terminal state: {}')


    def save_policy(self, file_path):
        """
        Save the current policy to a file.

        Parameters:
        - file_path: Path to the file where the policy should be saved
        """
        print(f"save_policy invoked")
        print(f"\tARG file_path = {(file_path)}")

    def load_policy(self, file_path):
        """
        Load a policy from a file.

        Parameters:
        - file_path: Path to the file from which the policy should be loaded
        """
        print(f"load_policy invoked")
        print(f"\tARG file_path object of type {type(file_path)}")

    def run_policy(self, env):
        """
        Run the loaded policy in the environment for one episode.

        Parameters:
        - env: The environment in which to run the policy

        Returns:
        - total_reward: Total reward accumulated in the episode
        """
        print(f"run_policy invoked")
        print(f"\tGot an env object of type {type(env)}")

# %%
env = Game(custom_obs=True, preprocess=preprocess, reward_shaping=reward_shaping, custome_observation_map=custome_observation_map)
"""
Insert you experiment code here
"""

env.seed(42)
max_steps = 500
log_every = 1  # For now log each step

# Policy dictionary.
# Consider making a dataclass or something similar
# We'll also save a score for each policy so we need to save it somehow
# So a more elaborate data structure could be useful. Namedtuple?
policy_dict = {
  TrivialPolicy: 'trivial_policy.json'
}

# For now - common hyperparameter values for q-learning as default
# These aren't being used yet.
hyperparameters = {
    'gamma': 0.9,
    'learning_rate': 0.1
}

# Action space
action_space = env.env.getActionSet()  # Not sure this makes sense. Weired values (None, 119).
action_space = [0, 1]  # Not sure this makes sense either. 0: fall, 1: fly.

# Observation space
observation_space = env.observation_space

# Training all policies
# Currently, use only a single policy.
# We might want to break this loop and treat each policy separately
for policy, policy_file in policy_dict.items():
    policy = policy(
        action_space,
        observation_space,
        hyperparameters['gamma'],
        hyperparameters['learning_rate']
        )
    policy.train(env, max_steps, log_every)
    policy.save_policy(policy_file)
# Out:
# Streaming output truncated to the last 5000 lines.
# Selected action: 1
# player_y (feaure 0#): 190
# player_vel (feaure 1#): -6
# next_pipe_dist_to_player (feaure 2#): 46
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 190
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #328
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [190  -6  46 169 249 190  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 190,
#         moving down at speed 6 (-6).
#
#         The next pipe is 46 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 19.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 185
# player_vel (feaure 1#): -5
# next_pipe_dist_to_player (feaure 2#): 42
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 186
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #329
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [185  -5  42 169 249 186  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 185,
#         moving down at speed 5 (-5).
#
#         The next pipe is 42 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 24.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 181
# player_vel (feaure 1#): -4
# next_pipe_dist_to_player (feaure 2#): 38
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 182
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #330
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [181  -4  38 169 249 182  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 181,
#         moving down at speed 4 (-4).
#
#         The next pipe is 38 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 28.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 178
# player_vel (feaure 1#): -3
# next_pipe_dist_to_player (feaure 2#): 34
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 178
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #331
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [178  -3  34 169 249 178  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 178,
#         moving down at speed 3 (-3).
#
#         The next pipe is 34 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 31.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 176
# player_vel (feaure 1#): -2
# next_pipe_dist_to_player (feaure 2#): 30
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 174
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #332
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [176  -2  30 169 249 174  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 176,
#         moving down at speed 2 (-2).
#
#         The next pipe is 30 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 33.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 175
# player_vel (feaure 1#): -1
# next_pipe_dist_to_player (feaure 2#): 26
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 170
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #333
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [175  -1  26 169 249 170  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 175,
#         moving down at speed 1 (-1).
#
#         The next pipe is 26 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 34.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 175
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 22
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 166
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #334
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [175   0  22 169 249 166  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 175,
#         moving down at speed 0 (0).
#
#         The next pipe is 22 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 34.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 176
# player_vel (feaure 1#): 1
# next_pipe_dist_to_player (feaure 2#): 18
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 162
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #335
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [176   1  18 169 249 162  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 176,
#         moving up at speed 1 (1).
#
#         The next pipe is 18 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 33.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 178
# player_vel (feaure 1#): 2
# next_pipe_dist_to_player (feaure 2#): 14
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 158
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #336
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [178   2  14 169 249 158  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 178,
#         moving up at speed 2 (2).
#
#         The next pipe is 14 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 31.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 181
# player_vel (feaure 1#): 3
# next_pipe_dist_to_player (feaure 2#): 10
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 154
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #337
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [181   3  10 169 249 154  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 181,
#         moving up at speed 3 (3).
#
#         The next pipe is 10 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 28.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 185
# player_vel (feaure 1#): 4
# next_pipe_dist_to_player (feaure 2#): 6
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 150
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #338
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [185   4   6 169 249 150  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 185,
#         moving up at speed 4 (4).
#
#         The next pipe is 6 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 24.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 190
# player_vel (feaure 1#): 5
# next_pipe_dist_to_player (feaure 2#): 2
# next_pipe_top_y (feaure 3#): 169
# next_pipe_bottom_y (feaure 4#): 249
# next_next_pipe_dist_to_player (feaure 5#): 146
# next_next_pipe_top_y (feaure 6#): 72
# next_next_pipe_bottom_y (feaure 7#): 152
# rendering frame and appending to video
# Episode #339
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [190   5   2 169 249 146  72 152]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 190,
#         moving up at speed 5 (5).
#
#         The next pipe is 2 units away,
#         with its top at 169 and bottom at 249.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 19.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 196
# player_vel (feaure 1#): 6
# next_pipe_dist_to_player (feaure 2#): 142
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 306
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #340
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [196   6 142  72 152 306  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 196,
#         moving up at speed 6 (6).
#
#         The next pipe is 142 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -84.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 188
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 138
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 302
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #341
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [188  -8 138  72 152 302  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 188,
#         moving down at speed 8 (-8).
#
#         The next pipe is 138 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -76.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 188
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 134
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 298
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #342
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [188   0 134  72 152 298  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 188,
#         moving down at speed 0 (0).
#
#         The next pipe is 134 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -76.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 180
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 130
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 294
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #343
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [180  -8 130  72 152 294  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 180,
#         moving down at speed 8 (-8).
#
#         The next pipe is 130 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -68.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 180
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 126
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 290
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #344
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [180   0 126  72 152 290  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 180,
#         moving down at speed 0 (0).
#
#         The next pipe is 126 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -68.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 172
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 122
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 286
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #345
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [172  -8 122  72 152 286  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 172,
#         moving down at speed 8 (-8).
#
#         The next pipe is 122 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -60.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 172
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 118
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 282
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #346
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [172   0 118  72 152 282  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 172,
#         moving down at speed 0 (0).
#
#         The next pipe is 118 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -60.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 164
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 114
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 278
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #347
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [164  -8 114  72 152 278  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 164,
#         moving down at speed 8 (-8).
#
#         The next pipe is 114 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -52.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 164
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 110
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 274
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #348
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [164   0 110  72 152 274  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 164,
#         moving down at speed 0 (0).
#
#         The next pipe is 110 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -52.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 156
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 106
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 270
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #349
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [156  -8 106  72 152 270  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 156,
#         moving down at speed 8 (-8).
#
#         The next pipe is 106 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -44.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 156
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 102
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 266
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #350
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [156   0 102  72 152 266  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 156,
#         moving down at speed 0 (0).
#
#         The next pipe is 102 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -44.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 148
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 98
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 262
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #351
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [148  -8  98  72 152 262  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 148,
#         moving down at speed 8 (-8).
#
#         The next pipe is 98 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -36.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 148
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 94
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 258
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #352
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [148   0  94  72 152 258  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 148,
#         moving down at speed 0 (0).
#
#         The next pipe is 94 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -36.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 140
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 90
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 254
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #353
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [140  -8  90  72 152 254  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 140,
#         moving down at speed 8 (-8).
#
#         The next pipe is 90 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -28.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 140
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 86
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 250
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #354
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [140   0  86  72 152 250  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 140,
#         moving down at speed 0 (0).
#
#         The next pipe is 86 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -28.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 132
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 82
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 246
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #355
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [132  -8  82  72 152 246  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 132,
#         moving down at speed 8 (-8).
#
#         The next pipe is 82 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -20.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 132
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 78
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 242
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #356
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [132   0  78  72 152 242  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 132,
#         moving down at speed 0 (0).
#
#         The next pipe is 78 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -20.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 124
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 74
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 238
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #357
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [124  -8  74  72 152 238  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 124,
#         moving down at speed 8 (-8).
#
#         The next pipe is 74 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -12.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 124
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 70
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 234
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #358
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [124   0  70  72 152 234  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 124,
#         moving down at speed 0 (0).
#
#         The next pipe is 70 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -12.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 116
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 66
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 230
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #359
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [116  -8  66  72 152 230  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 116,
#         moving down at speed 8 (-8).
#
#         The next pipe is 66 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -4.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 108
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 62
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 226
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #360
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [108  -8  62  72 152 226  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 108,
#         moving down at speed 8 (-8).
#
#         The next pipe is 62 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 4.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 101
# player_vel (feaure 1#): -7
# next_pipe_dist_to_player (feaure 2#): 58
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 222
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #361
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [101  -7  58  72 152 222  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 101,
#         moving down at speed 7 (-7).
#
#         The next pipe is 58 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 11.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 95
# player_vel (feaure 1#): -6
# next_pipe_dist_to_player (feaure 2#): 54
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 218
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #362
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 95  -6  54  72 152 218  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 95,
#         moving down at speed 6 (-6).
#
#         The next pipe is 54 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 17.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 90
# player_vel (feaure 1#): -5
# next_pipe_dist_to_player (feaure 2#): 50
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 214
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #363
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 90  -5  50  72 152 214  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 90,
#         moving down at speed 5 (-5).
#
#         The next pipe is 50 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 22.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 86
# player_vel (feaure 1#): -4
# next_pipe_dist_to_player (feaure 2#): 46
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 210
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #364
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 86  -4  46  72 152 210  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 86,
#         moving down at speed 4 (-4).
#
#         The next pipe is 46 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 26.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 83
# player_vel (feaure 1#): -3
# next_pipe_dist_to_player (feaure 2#): 42
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 206
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #365
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 83  -3  42  72 152 206  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 83,
#         moving down at speed 3 (-3).
#
#         The next pipe is 42 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 29.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 81
# player_vel (feaure 1#): -2
# next_pipe_dist_to_player (feaure 2#): 38
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 202
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #366
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 81  -2  38  72 152 202  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 81,
#         moving down at speed 2 (-2).
#
#         The next pipe is 38 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 31.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 80
# player_vel (feaure 1#): -1
# next_pipe_dist_to_player (feaure 2#): 34
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 198
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #367
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 80  -1  34  72 152 198  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 80,
#         moving down at speed 1 (-1).
#
#         The next pipe is 34 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 32.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 80
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 30
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 194
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #368
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 80   0  30  72 152 194  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 80,
#         moving down at speed 0 (0).
#
#         The next pipe is 30 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 32.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 81
# player_vel (feaure 1#): 1
# next_pipe_dist_to_player (feaure 2#): 26
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 190
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #369
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 81   1  26  72 152 190  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 81,
#         moving up at speed 1 (1).
#
#         The next pipe is 26 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 31.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 83
# player_vel (feaure 1#): 2
# next_pipe_dist_to_player (feaure 2#): 22
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 186
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #370
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 83   2  22  72 152 186  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 83,
#         moving up at speed 2 (2).
#
#         The next pipe is 22 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 29.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 86
# player_vel (feaure 1#): 3
# next_pipe_dist_to_player (feaure 2#): 18
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 182
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #371
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 86   3  18  72 152 182  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 86,
#         moving up at speed 3 (3).
#
#         The next pipe is 18 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 26.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 90
# player_vel (feaure 1#): 4
# next_pipe_dist_to_player (feaure 2#): 14
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 178
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #372
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 90   4  14  72 152 178  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 90,
#         moving up at speed 4 (4).
#
#         The next pipe is 14 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 22.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 95
# player_vel (feaure 1#): 5
# next_pipe_dist_to_player (feaure 2#): 10
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 174
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #373
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 95   5  10  72 152 174  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 95,
#         moving up at speed 5 (5).
#
#         The next pipe is 10 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 17.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 101
# player_vel (feaure 1#): 6
# next_pipe_dist_to_player (feaure 2#): 6
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 170
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #374
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [101   6   6  72 152 170  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 101,
#         moving up at speed 6 (6).
#
#         The next pipe is 6 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 11.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 108
# player_vel (feaure 1#): 7
# next_pipe_dist_to_player (feaure 2#): 2
# next_pipe_top_y (feaure 3#): 72
# next_pipe_bottom_y (feaure 4#): 152
# next_next_pipe_dist_to_player (feaure 5#): 166
# next_next_pipe_top_y (feaure 6#): 21
# next_next_pipe_bottom_y (feaure 7#): 101
# rendering frame and appending to video
# Episode #375
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [108   7   2  72 152 166  21 101]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 108,
#         moving up at speed 7 (7).
#
#         The next pipe is 2 units away,
#         with its top at 72 and bottom at 152.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 4.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 116
# player_vel (feaure 1#): 8
# next_pipe_dist_to_player (feaure 2#): 162
# next_pipe_top_y (feaure 3#): 21
# next_pipe_bottom_y (feaure 4#): 101
# next_next_pipe_dist_to_player (feaure 5#): 306
# next_next_pipe_top_y (feaure 6#): 107
# next_next_pipe_bottom_y (feaure 7#): 187
# rendering frame and appending to video
# Episode #376
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [116   8 162  21 101 306 107 187]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 116,
#         moving up at speed 8 (8).
#
#         The next pipe is 162 units away,
#         with its top at 21 and bottom at 101.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -55.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 108
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 158
# next_pipe_top_y (feaure 3#): 21
# next_pipe_bottom_y (feaure 4#): 101
# next_next_pipe_dist_to_player (feaure 5#): 302
# next_next_pipe_top_y (feaure 6#): 107
# next_next_pipe_bottom_y (feaure 7#): 187
# rendering frame and appending to video
# Episode #377
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [108  -8 158  21 101 302 107 187]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 108,
#         moving down at speed 8 (-8).
#
#         The next pipe is 158 units away,
#         with its top at 21 and bottom at 101.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -47.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 108
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 154
# next_pipe_top_y (feaure 3#): 21
# next_pipe_bottom_y (feaure 4#): 101
# next_next_pipe_dist_to_player (feaure 5#): 298
# next_next_pipe_top_y (feaure 6#): 107
# next_next_pipe_bottom_y (feaure 7#): 187
# rendering frame and appending to video
# Episode #378
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [108   0 154  21 101 298 107 187]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 108,
#         moving down at speed 0 (0).
#
#         The next pipe is 154 units away,
#         with its top at 21 and bottom at 101.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -47.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 100
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 150
# next_pipe_top_y (feaure 3#): 21
# next_pipe_bottom_y (feaure 4#): 101
# next_next_pipe_dist_to_player (feaure 5#): 294
# next_next_pipe_top_y (feaure 6#): 107
# next_next_pipe_bottom_y (feaure 7#): 187
# rendering frame and appending to video
# Episode #379
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [100  -8 150  21 101 294 107 187]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 100,
#         moving down at speed 8 (-8).
#
#         The next pipe is 150 units away,
#         with its top at 21 and bottom at 101.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -39.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 100
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 146
# next_pipe_top_y (feaure 3#): 21
# next_pipe_bottom_y (feaure 4#): 101
# next_next_pipe_dist_to_player (feaure 5#): 290
# next_next_pipe_top_y (feaure 6#): 107
# next_next_pipe_bottom_y (feaure 7#): 187
# rendering frame and appending to video
# Episode #380
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [100   0 146  21 101 290 107 187]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 100,
#         moving down at speed 0 (0).
#
#         The next pipe is 146 units away,
#         with its top at 21 and bottom at 101.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -39.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 92
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 142
# next_pipe_top_y (feaure 3#): 21
# next_pipe_bottom_y (feaure 4#): 101
# next_next_pipe_dist_to_player (feaure 5#): 286
# next_next_pipe_top_y (feaure 6#): 107
# next_next_pipe_bottom_y (feaure 7#): 187
# rendering frame and appending to video
# Episode #381
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 92  -8 142  21 101 286 107 187]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 92,
#         moving down at speed 8 (-8).
#
#         The next pipe is 142 units away,
#         with its top at 21 and bottom at 101.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -31.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 92
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 138
# next_pipe_top_y (feaure 3#): 21
# next_pipe_bottom_y (feaure 4#): 101
# next_next_pipe_dist_to_player (feaure 5#): 282
# next_next_pipe_top_y (feaure 6#): 107
# next_next_pipe_bottom_y (feaure 7#): 187
# rendering frame and appending to video
# Episode #382
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 92   0 138  21 101 282 107 187]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 92,
#         moving down at speed 0 (0).
#
#         The next pipe is 138 units away,
#         with its top at 21 and bottom at 101.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -31.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 84
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 134
# next_pipe_top_y (feaure 3#): 21
# next_pipe_bottom_y (feaure 4#): 101
# next_next_pipe_dist_to_player (feaure 5#): 278
# next_next_pipe_top_y (feaure 6#): 107
# next_next_pipe_bottom_y (feaure 7#): 187
# rendering frame and appending to video
# Episode #383
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [ 84  -8 134  21 101 278 107 187]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 84,
#         moving down at speed 8 (-8).
#
# ...
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 196
# player_vel (feaure 1#): -5
# next_pipe_dist_to_player (feaure 2#): 26
# next_pipe_top_y (feaure 3#): 177
# next_pipe_bottom_y (feaure 4#): 257
# next_next_pipe_dist_to_player (feaure 5#): 190
# next_next_pipe_top_y (feaure 6#): 57
# next_next_pipe_bottom_y (feaure 7#): 137
# rendering frame and appending to video
# Episode #482
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [196  -5  26 177 257 190  57 137]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 196,
#         moving down at speed 5 (-5).
#
#         The next pipe is 26 units away,
#         with its top at 177 and bottom at 257.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 21.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 192
# player_vel (feaure 1#): -4
# next_pipe_dist_to_player (feaure 2#): 22
# next_pipe_top_y (feaure 3#): 177
# next_pipe_bottom_y (feaure 4#): 257
# next_next_pipe_dist_to_player (feaure 5#): 186
# next_next_pipe_top_y (feaure 6#): 57
# next_next_pipe_bottom_y (feaure 7#): 137
# rendering frame and appending to video
# Episode #483
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [192  -4  22 177 257 186  57 137]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 192,
#         moving down at speed 4 (-4).
#
#         The next pipe is 22 units away,
#         with its top at 177 and bottom at 257.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 25.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 189
# player_vel (feaure 1#): -3
# next_pipe_dist_to_player (feaure 2#): 18
# next_pipe_top_y (feaure 3#): 177
# next_pipe_bottom_y (feaure 4#): 257
# next_next_pipe_dist_to_player (feaure 5#): 182
# next_next_pipe_top_y (feaure 6#): 57
# next_next_pipe_bottom_y (feaure 7#): 137
# rendering frame and appending to video
# Episode #484
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [189  -3  18 177 257 182  57 137]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 189,
#         moving down at speed 3 (-3).
#
#         The next pipe is 18 units away,
#         with its top at 177 and bottom at 257.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 28.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 187
# player_vel (feaure 1#): -2
# next_pipe_dist_to_player (feaure 2#): 14
# next_pipe_top_y (feaure 3#): 177
# next_pipe_bottom_y (feaure 4#): 257
# next_next_pipe_dist_to_player (feaure 5#): 178
# next_next_pipe_top_y (feaure 6#): 57
# next_next_pipe_bottom_y (feaure 7#): 137
# rendering frame and appending to video
# Episode #485
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [187  -2  14 177 257 178  57 137]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 187,
#         moving down at speed 2 (-2).
#
#         The next pipe is 14 units away,
#         with its top at 177 and bottom at 257.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 30.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 186
# player_vel (feaure 1#): -1
# next_pipe_dist_to_player (feaure 2#): 10
# next_pipe_top_y (feaure 3#): 177
# next_pipe_bottom_y (feaure 4#): 257
# next_next_pipe_dist_to_player (feaure 5#): 174
# next_next_pipe_top_y (feaure 6#): 57
# next_next_pipe_bottom_y (feaure 7#): 137
# rendering frame and appending to video
# Episode #486
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [186  -1  10 177 257 174  57 137]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 186,
#         moving down at speed 1 (-1).
#
#         The next pipe is 10 units away,
#         with its top at 177 and bottom at 257.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 31.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 186
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 6
# next_pipe_top_y (feaure 3#): 177
# next_pipe_bottom_y (feaure 4#): 257
# next_next_pipe_dist_to_player (feaure 5#): 170
# next_next_pipe_top_y (feaure 6#): 57
# next_next_pipe_bottom_y (feaure 7#): 137
# rendering frame and appending to video
# Episode #487
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [186   0   6 177 257 170  57 137]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 186,
#         moving down at speed 0 (0).
#
#         The next pipe is 6 units away,
#         with its top at 177 and bottom at 257.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 31.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 187
# player_vel (feaure 1#): 1
# next_pipe_dist_to_player (feaure 2#): 2
# next_pipe_top_y (feaure 3#): 177
# next_pipe_bottom_y (feaure 4#): 257
# next_next_pipe_dist_to_player (feaure 5#): 166
# next_next_pipe_top_y (feaure 6#): 57
# next_next_pipe_bottom_y (feaure 7#): 137
# rendering frame and appending to video
# Episode #488
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [187   1   2 177 257 166  57 137]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 187,
#         moving up at speed 1 (1).
#
#         The next pipe is 2 units away,
#         with its top at 177 and bottom at 257.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: 30.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 1
# player_y (feaure 0#): 189
# player_vel (feaure 1#): 2
# next_pipe_dist_to_player (feaure 2#): 162
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 306
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #489
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [189   2 162  57 137 306 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 189,
#         moving up at speed 2 (2).
#
#         The next pipe is 162 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -92.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 181
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 158
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 302
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #490
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [181  -8 158  57 137 302 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 181,
#         moving down at speed 8 (-8).
#
#         The next pipe is 158 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -84.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 181
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 154
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 298
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #491
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [181   0 154  57 137 298 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 181,
#         moving down at speed 0 (0).
#
#         The next pipe is 154 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -84.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 173
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 150
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 294
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #492
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [173  -8 150  57 137 294 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 173,
#         moving down at speed 8 (-8).
#
#         The next pipe is 150 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -76.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 173
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 146
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 290
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #493
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [173   0 146  57 137 290 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 173,
#         moving down at speed 0 (0).
#
#         The next pipe is 146 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -76.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 165
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 142
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 286
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #494
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [165  -8 142  57 137 286 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 165,
#         moving down at speed 8 (-8).
#
#         The next pipe is 142 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -68.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 165
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 138
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 282
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #495
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [165   0 138  57 137 282 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 165,
#         moving down at speed 0 (0).
#
#         The next pipe is 138 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -68.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 157
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 134
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 278
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #496
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [157  -8 134  57 137 278 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 157,
#         moving down at speed 8 (-8).
#
#         The next pipe is 134 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -60.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 157
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 130
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 274
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #497
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [157   0 130  57 137 274 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 157,
#         moving down at speed 0 (0).
#
#         The next pipe is 130 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -60.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 149
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 126
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 270
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #498
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [149  -8 126  57 137 270 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 149,
#         moving down at speed 8 (-8).
#
#         The next pipe is 126 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -52.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 149
# player_vel (feaure 1#): 0
# next_pipe_dist_to_player (feaure 2#): 122
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 266
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# Episode #499
# select_action invoked
# 	Got an observation object of type <class 'numpy.ndarray'>
# [149   0 122  57 137 266 149 229]
#
#         This is what I understand regarding current observation:
#
#         Bird at altitude 149,
#         moving down at speed 0 (0).
#
#         The next pipe is 122 units away,
#         with its top at 57 and bottom at 137.
#
#         This means that bird is above the next gap.
#
#         Distance from the middle of the gap: -52.0.
#
#         We currently ignore the 'next next' pipe.
#
# Selected action: 0
# player_y (feaure 0#): 141
# player_vel (feaure 1#): -8
# next_pipe_dist_to_player (feaure 2#): 118
# next_pipe_top_y (feaure 3#): 57
# next_pipe_bottom_y (feaure 4#): 137
# next_next_pipe_dist_to_player (feaure 5#): 262
# next_next_pipe_top_y (feaure 6#): 149
# next_next_pipe_bottom_y (feaure 7#): 229
# rendering frame and appending to video
# save_policy invoked
# 	ARG file_path = trivial_policy.json

# %%
embed_mp4('experiment1.mp4')
# Out:
#   <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#   Your browser does not support the video tag.
#   </video>

# %% [markdown]
# ## Validation

# %% [markdown]
# #### Validation Section
#
# In this section, you will validate your agent’s performance using the best-performing configuration identified in the experimentation phase. This validation step should be less exhaustive than the experimentation section but should provide sufficient evidence of your agent's consistency and stability.
#
# 1. **Run Validation Trials**:
#    - Using the chosen configuration, run the agent in the environment for **multiple trials** (e.g., 5-10 episodes) to test its reliability.
#    - Observe the agent's performance across these trials to confirm whether it consistently achieves or exceeds the target score of 10.
#
# 2. **Provide Key Summaries**:
#    - **Performance Metrics**: Summarize the agent’s performance with key metrics such as average score, highest score, and variance across trials.
#    - **Graphs** (Optional): Include basic graphs showing score progression or any other relevant metric, if they provide additional insight into the agent's stability.
#
# 3. **Brief Analysis**:
#    - Reflect on the agent's performance in validation. Note any patterns or inconsistencies and provide a short explanation of how these results align (or differ) from your expectations based on the experimentation phase.
#
# *Note*: This validation section should confirm and strengthen the results of your experimentation, focusing on reliability and consistency rather than extensive analysis.
#
# *Note*: Store the agent's policy to files since you asked to provide aditional notbook that loads the agent policy

# %%
"""
Insert you validation code here

Iterate over (Policy_name, policy_filename)
  * trivial_policy = TrivialPolicy()
  * trivial_policy.load_policy('trivial_policy.txt')
  * trivial_policy.run_policy()


e.g. consider

scores list?
for policy, policy_file in policy_dict.items():
    policy = policy()
    policy.load_policy(policy_file)
    policy.run_policy()
    # save score of experiment


# Select best policy and present statistics?
"""
